# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Users/user/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
data = pd.read_csv("dataLC.csv")

# %%
data.head(5)
# Out:
#    study_id  gender  age who3g  bmi fev1pc_t0 dumsmok2 t_ct_loc hist4g  \
# 0         1       1   63     2   22        82        2        6      4
# 1         2       2   66     2   28        62        2        1      1
# 2         3       1   58     1   25        95        2        4      1
# 3         4       2   63     2   28        73        2        6      2
# 4         5       1   59     1   20       124        2        6      4
#
#   countpet_all6g  ... timing group yearrt  eqd2  ott  gtv1  tumorload_total  \
# 0              4  ...      3     4   2008    53   28   192              214
# 1              4  ...      3     4   2010    55   32   154              169
# 2              1  ...      3     4   2008    65   32    85               85
# 3              6  ...      3     4   2007    63   36    98              120
# 4              3  ...      3     4   2008    65   36    62              136
#
#    survmonth  survyear  deadstat
# 0         16         1         1
# ...

# %%
# 1. Age Distribution
plt.figure(figsize=(10, 6))
sns.histplot(data['age'], kde=True, bins=30)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()
# Out:
# /Users/user/opt/anaconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 2. BMI Distribution
plt.figure(figsize=(10, 6))
sns.histplot(demographics_df['bmi'], kde=True, bins=30)
plt.title("BMI Distribution")
plt.xlabel("BMI")
plt.ylabel("Count")
plt.show()

# 3. BMI by Gender (Boxplot)
plt.figure(figsize=(10, 6))
sns.boxplot(x='gender', y='bmi', data=demographics_df)
plt.title("BMI by Gender")
plt.xlabel("Gender")
plt.ylabel("BMI")
plt.show()

# 4. Age vs. BMI Scatterplot
correlation = demographics_df[['age', 'bmi']].corr().loc['age', 'bmi']
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='bmi', hue='gender', data=demographics_df)
plt.title(f"Age vs. BMI (Correlation: {correlation:.2f})")
plt.xlabel("Age")
plt.ylabel("BMI")
plt.legend(title="Gender")
plt.show()
